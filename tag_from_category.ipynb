# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaitaliV/Location-Extractor/blob/main/tag_from_category.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
# !git clone https://github.com/ChaitaliV/Location-Extractor
# Out:
# Cloning into 'Location-Extractor'...
# remote: Enumerating objects: 338, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 338 (delta 116), reused 108 (delta 59), pack-reused 129
# Receiving objects: 100% (338/338), 575.69 KiB | 2.33 MiB/s, done.
# Resolving deltas: 100% (189/189), done.

# %%
base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
api_key = "AIzaSyCU7kaDfhZIM4bbJVujlGlhdXphUPke1yY"

# %%
"""Categories: site-seeing, food, cafe, deserts, entertainemnt, bars and clubs, shopping, self care"""
# Out:
# 'Categories: site-seeing, food, cafe, deserts, entertainemnt, bars and clubs, shopping, self care'

# %%
def fetch_place_details(place_name):
      # Set up the parameters for the API request
      global result
      params = {
          'key': api_key,
          'input': place_name,
          'inputtype': 'textquery',
          'fields': 'types'
      }

      # Send the API request
      response = requests.get(base_url, params=params).json()

      # Check if the response contains any results
      if response['status'] == 'ZERO_RESULTS':
          result = ''
      else:
          result = response['candidates'][0]
          # Get the place ID of the first result (assuming it is the correct restaurant)

          details= result['types'][0]
          

          return details

# %%
fetch_place_details('funcity, Chandigarh')
# Out:
# 'point_of_interest'

# %%
df = pd.read_csv('Location-Extractor/Data/places_names.csv')

# %%
df
# Out:
#       Unnamed: 0                         Place Name Tag from name  \
# 0              0                    VR Surat, Surat          None
# 1              1                  Iscon Mall, Surat          Mall
# 2              2                Central Mall, Surat          Mall
# 3              3               RahulRaj Mall, Surat          Mall
# 4              4                  Big Bazaar, Surat          None
# ...          ...                                ...           ...
# 1235        1235  Maner Sharif - Maner (near Patna)          None
# 1236        1236             Patna Junction - Patna          None
# 1237        1237          Patna Secretariat - Patna          None
# 1238        1238                 Golak Bari - Patna          None
# 1239        1239                   Eco Park - Patna          Park
#
#      Google places Type
# 0         shopping_mall
# 1     point_of_interest
# 2         shopping_mall
# 3         shopping_mall
# 4       furniture_store
# ...                 ...
# 1235           locality
# 1236              route
# 1237  point_of_interest
# 1238                NaN
# 1239               park
#
# [1240 rows x 4 columns]

# %%
df['Google places Type'][:].unique()
# Out:
# array(['shopping_mall', 'point_of_interest', 'furniture_store',
#        'neighborhood', 'premise', 'parking', 'clothing_store',
#        'physiotherapist', 'jewelry_store', 'store', nan, 'supermarket',
#        'restaurant', 'florist', 'stadium', 'grocery_or_supermarket',
#        'tourist_attraction', 'university', 'bakery', 'general_contractor',
#        'route', 'sublocality_level_1', 'food', 'sublocality_level_2',
#        'sublocality_level_3', 'museum', 'art_gallery', 'natural_feature',
#        'locality', 'zoo', 'hindu_temple', 'casino', 'lodging', 'mosque',
#        'park', 'taxi_stand', 'school', 'spa', 'hair_care', 'beauty_salon',
#        'bar', 'cafe', 'night_club', 'courthouse', 'meal_takeaway',
#        'book_store', 'gym', 'meal_delivery', 'movie_theater',
#        'bicycle_store', 'shoe_store', 'place_of_worship', 'train_station',
#        'colloquial_area', 'church', 'travel_agency', 'campground',
#        'administrative_area_level_3', 'local_government_office'],
#       dtype=object)

# %%
places = {
    'Food': ['Bhojpuri', 'Sushi', 'African', 'Indian', 'Street Food', 'Bhaji Pav', 'Tea Shop', 'Lassi', 'Specialty Food', 'Masala Dosa', 'Dhaba', 'Paneer Tikka', 'Bengali', 'Naan', 'Chole Bhature', 'Kadai Paneer', 'Kathiyawadi', 'Oyster Bar', 'Greek', 'Pho Noodle', 'South Indian', 'Idli'],
    'Cafe': ['Coffee Shop', 'Cafe'],
    'Desserts': [ 'Ice Cream','Bakery', 'Cake Shop', 'Lassi Shop', 'Dessert Shop', 'Malai Kofta', 'Gelato', 'Cheesecake', 'Kulfi', 'Chaat', 'Gulab Jamun', 'Jalebi', 'Pesarattu', 'Rasgulla', 'Rasmalai', 'Jodhpuri', 'Rice Terrace', 'Misal', 'Chole Bhature', 'Gajar Halwa', 'Rogan Josh', 'Rajma Chawal', 'Kheer', 'Vada Pav', 'Samosa', 'Kachori', 'Pakora', 'Chapati', 'Danish', 'Cupcake Shop'],
    'Shopping': ['Saree','Craft Market', 'Mall', 'Thrift Store', 'Electronics Store', 'Grocery Store', 'Shopping Street', 'Appliance', 'Convenience', 'Outlet Store', 'Computer Store', 'Department Store', 'Fashion Boutique', 'Chocolatier', 'Bakery', 'Wine Tasting Room', 'Cakery', 'Shopping Center', 'Toy Store', 'Jewelry Store', 'Bookstore', 'Antique Store', 'Gift Shop', 'Clothing Store', 'Fruit Stand', 'Accessories', 'Supermarket'],
    'Sightseeing': ['Pyramids','Monestry', 'Museum', 'Island', 'Peak', 'Landmark', 'Dam', 'Airport', 'Street Food', 'Auto Parts', 'Garden Center', 'Pedestrian Street', 'Statue', 'Garden', 'Archery Range', 'Library', 'University', 'Flea Market', 'Garden', 'Gallery', 'Fort', 'Memorial', 'Lighthouse', 'Bridge', 'Heritage', 'Observatory', 'Planetarium', 'Archaeological Site', 'Waterfalls', 'Waterfall', 'Picnic Spot', 'Ruins', 'Shrine', 'Monument', 'Church', 'Lake', 'Forest', 'Mountain Range', 'Bay', 'National Park', 'Plaza'],
    'Selfcare': ['Sauna', 'Tanning Salon', 'Spa', 'Acupuncture', 'Holistic Center','Acupuncture', 'Ayurvedic Center', 'Infrared Sauna', 'Mindfulness Studio', 'Massage Center', 'Halotherapy Center', 'Foot Spa', 'Thermal Spa', 'Wellness Center', 'Holistic Center', 'Reflexology', 'Hair Salon', 'Beauty Salon', 'Health Spa', 'Beauty Spa', 'Nail Salon', 'Salon'],
    'Entertainment': ['Bar', 'Bar', 'Lounge', 'Bar', 'Distillery', 'Cafe', 'Karaoke Bar', 'English Pub', 'Nightclub', 'Comedy Club', 'Sports Bar', 'Wine Bar', 'Live Music Venue', 'Dance Club', 'Piano Bar', 'Brewery', 'Cocktail Bar', 'Jazz Club', 'Gastropub', 'Irish Pub', 'Hookah Bar', 'Salsa Club', 'Rooftop Bar', 'Pool Hall', 'Speakeasy', 'Beer Garden', 'Biker Bar', 'Tiki Bar', 'Wine Tasting Room', 'Tapas Bar', 'Dive Bar', 'Pub', 'Arcade', 'Bowling Alley', 'Casino', 'Billiards', 'Mini Golf', 'Movie Theater', 'Theme Park', 'Amusement Park', 'Water Park', 'Escape Room', 'Concert Hall', 'Theater', 'Opera House', 'Cinema', 'Stadium', 'Zoo', 'Aquarium']
}


category_mapping = {
    'shopping_mall': 'shopping',
    'point_of_interest': 'site-seeing',
    'furniture_store': 'shopping',
    'neighborhood': 'site-seeing',
    'premise': 'site-seeing',
    'parking': 'site-seeing',
    'clothing_store': 'shopping',
    'physiotherapist': 'self care',
    'jewelry_store': 'shopping',
    'store': 'shopping',
    'supermarket': 'shopping',
    'restaurant': 'food',
    'florist': 'shopping',
    'stadium': 'entertainment',
    'grocery_or_supermarket': 'shopping',
    'tourist_attraction': 'site-seeing',
    'university': 'site-seeing',
    'bakery': 'deserts',
    'general_contractor': 'site-seeing',
    'route': 'site-seeing',
    'sublocality_level_1': 'site-seeing',
    'food': 'food',
    'sublocality_level_2': 'site-seeing',
    'sublocality_level_3': 'site-seeing',
    'museum': 'site-seeing',
    'art_gallery': 'site-seeing',
    'natural_feature': 'site-seeing',
    'locality': 'site-seeing',
    'zoo': 'site-seeing',
    'hindu_temple': 'site-seeing',
    'casino': 'entertainment',
    'lodging': 'entertainment',
    'mosque': 'site-seeing',
    'park': 'site-seeing',
    'taxi_stand': 'site-seeing',
    'school': 'site-seeing',
    'spa': 'self care',
    'hair_care': 'self care',
    'beauty_salon': 'self care',
    'bar': 'bars and clubs',
    'cafe': 'cafe',
    'night_club': 'bars and clubs',
    'courthouse': 'site-seeing',
    'meal_takeaway': 'food',
    'book_store': 'shopping',
    'gym': 'self care',
    'meal_delivery': 'food',
    'movie_theater': 'entertainment',
    'bicycle_store': 'shopping',
    'shoe_store': 'shopping',
    'place_of_worship': 'site-seeing',
    'train_station': 'site-seeing',
    'colloquial_area': 'site-seeing',
    'church': 'site-seeing',
    'travel_agency': 'site-seeing',
    'campground': 'site-seeing',
    'administrative_area_level_3': 'site-seeing',
    'local_government_office': 'site-seeing'
}

def categorize_place_type(place_type):
    if isinstance(place_type, str):  # Check if the value is a string
        if place_type in category_mapping:
            return category_mapping[place_type]
        elif 'food' in place_type or 'cafe' in place_type or 'desert' in place_type or 'bar' in place_type:
            return 'food'
    return 'uncategorized'


# Apply the categorize_place_type function to your pandas column
df['category'] = df['Google places Type'].apply(categorize_place_type)

# %%
df['category']
# Out:
# 0            shopping
# 1         site-seeing
# 2            shopping
# 3            shopping
# 4            shopping
#             ...
# 1235      site-seeing
# 1236      site-seeing
# 1237      site-seeing
# 1238    uncategorized
# 1239      site-seeing
# Name: category, Length: 1240, dtype: object

# %%
data = [
    "Cafe Coffee Day Chandigarh",
    "Nik Baker's Chandigarh",
    "TGI Friday's Chandigarh",
    "Barbeque Nation Chandigarh",
    "Rock Garden Chandigarh",
    "Sukhna Lake Chandigarh",
    "Elante Mall Chandigarh",
    "Sector 17 Market Chandigarh",
    "Sector 22 Market Chandigarh",
    "Chandigarh Golf Club",
    "Terrace Garden Chandigarh",
    "Mohali Cricket Stadium",
    "Sector 26 Club Chandigarh",
    "Paara Nightclub Chandigarh",
    "Sector 7 Social Chandigarh",
    "Sector 9 Market Chandigarh",
    "Iskate Chandigarh",
    "Le Corbusier Centre Chandigarh",
    "Capitol Complex Chandigarh",
    "Zakir Hussain Rose Garden Chandigarh",
    "Sindhi Sweets Chandigarh",
    "Gopal Sweets Chandigarh",
    "O2 Spa Chandigarh",
    "VLCC Chandigarh",
    "Taj Chandigarh",
    "Sector 43 Gurudwara Chandigarh",
    "Sector 17 Plaza Chandigarh",
    "Punjab Cricket Association Stadium Mohali",
    "Cactus Garden Chandigarh",
    "Funcity Chandigarh",
    "Sukhna Wildlife Sanctuary Chandigarh"
]

# %%
tag_2 = []
google_type = []
for place in data:
  google_data = fetch_place_details(place)
  google_type.append(google_data)
  tag_2.append(categorize_place_type(google_data))

# %%
google_type
# Out:
# ['cafe',
#  'bakery',
#  'restaurant',
#  'restaurant',
#  'sublocality_level_2',
#  'natural_feature',
#  'premise',
#  'transit_station',
#  'route',
#  'point_of_interest',
#  'park',
#  'stadium',
#  'night_club',
#  'night_club',
#  'restaurant',
#  'transit_station',
#  'point_of_interest',
#  'tourist_attraction',
#  'tourist_attraction',
#  'park',
#  'bakery',
#  'bakery',
#  'spa',
#  'beauty_salon',
#  'lodging',
#  'place_of_worship',
#  'point_of_interest',
#  'stadium',
#  'tourist_attraction',
#  'point_of_interest',
#  'tourist_attraction']

# %%
g_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-9b8e2a17a065> in <cell line: 1>()
# ----> 1 g_2
#
# NameError: name 'g_2' is not defined

# %%
tag_2
# Out:
# ['cafe',
#  'deserts',
#  'food',
#  'food',
#  'site-seeing',
#  'site-seeing',
#  'site-seeing',
#  'uncategorized',
#  'site-seeing',
#  'site-seeing',
#  'site-seeing',
#  'entertainment',
#  'bars and clubs',
#  'bars and clubs',
#  'food',
#  'uncategorized',
#  'site-seeing',
#  'site-seeing',
#  'site-seeing',
#  'site-seeing',
#  'deserts',
#  'deserts',
#  'self care',
#  'self care',
#  'entertainment',
#  'site-seeing',
#  'site-seeing',
#  'entertainment',
#  'site-seeing',
#  'site-seeing',
#  'site-seeing']

# %%
df2 = pd.DataFrame({'place':data,'tag category':tag_2})

# %%
df2.to_csv('tag2.csv')

# %%
tag1 = pd.read_csv('Location-Extractor/Data/tags_for_tag.csv')

# %%
actual = tag1['Tags'][:].unique()

# %%
actual
# Out:
# array(['Monestry', 'Cruise', 'Museum', 'Craft ', 'Mall', 'Saree',
#        'Lounge', 'Bhojpuri', 'Sauna', 'Grocery', 'Sushi', 'African',
#        'Snowboarding', 'Bar', 'Indian', 'Island', 'Bistro', 'Resort',
#        'Peak', 'Thrift Store', 'Electronics', 'Sailing', 'Airport',
#        'Bhaji Pav', 'Tanning Salon', 'Tea Shop', 'Dam', 'Street Food',
#        'Landmark', 'Auto Parts ', 'Shopping Street', 'Appliance',
#        'Convenience', 'Cocktail Bar', 'Lassi', 'Acupuncture',
#        'Specialty Food', 'Paratha', 'Sanctuary', 'Spa', 'North Indian',
#        'Garden Center', 'Pedestrian Street', 'Kebab House', 'Kathiyawadi',
#        'Taco Stand', 'Oyster Bar', 'Distillery', 'Cafe', 'Ethiopian',
#        'Indonesian', 'Peruvian', 'Hill', 'Archery Range', 'Gourmet Food',
#        'Masala Dosa', 'Deli', 'Outlet', 'Zoo', 'Computer', 'Egyptian',
#        'Idli House', 'Cake Shop', 'Stargazing Spot', 'Salt Cave',
#        'Mindfulness ', 'Masjid', 'English Pub', 'Statue', 'Mangalorean',
#        'Kadai Paneer', 'Locho', 'Dessert', 'Greek ', 'Pho Noodle',
#        'South Indian', 'Ayurvedic ', 'Library', 'Restaurant',
#        'University', 'Flea Market', 'Kebab', 'Chole Bhature ', 'Garden',
#        'Infrared Sauna', 'Buddihist', 'Boutique', 'Manipuri', 'Rasmalai',
#        'Amusement Park', 'Swedish', 'Ski Resort', 'Kerala', 'Home Decor',
#        'Jalebi', 'Pesarattu', 'Roti', 'Department Store', 'Wine Tasting ',
#        'Restro', 'Retreat Center', 'Greek', 'Thali ', 'Vegan', 'Cakery',
#        'cruise', 'Chocolatier', 'Shopping', 'Bakery', 'Dutch',
#        'Paneer Tikka ', 'Veg', 'Juice', 'Bengali', 'Vav',
#        'Historical Site', 'River', 'Naan', 'Tandoori', 'Gurudwara',
#        'Resort ', 'Pani Puri ', 'Paragliding', 'Valley', 'German',
#        'Ice Cream', 'Pilates ', 'Donuts', 'Mount', 'Hair Salon',
#        'Vineyard', 'Fashion', 'Goan', 'Biryani', 'Beaches', 'Kachori',
#        'City Tour', 'Garhwali', 'Jodhpuri', 'Cheese',
#        'Archaeological Park', 'Day Spa', 'Jewelry ', 'Drive-In',
#        'Helicopter Tour', 'Surfing', 'Gallery', 'Market', 'Italian',
#        'Baker', 'Beach Shack', 'Maharashtrian', 'Lighthouse', 'Wildlife',
#        'Spanish', 'Dhaba', 'Vietnamese', 'Anglo-Indian', 'Cave', 'Mizo',
#        'French', 'Physical Therapy', 'Pub', 'Super Market', 'Sandwich ',
#        'Steam Room', 'Taproom', 'Pastry ', 'Playground', 'Video Game',
#        'Fort', 'Toy Store', 'Fine Dining', 'Couture', 'Malai Kofta ',
#        'Opera House', 'Food Court', 'Hot Springs', 'Food Market',
#        'Conference ', 'Noodle', 'Photography ', 'Sports ',
#        'Holistic Center', 'Family ', 'Safari', 'Historical Tour',
#        'Rasgulla', 'Clinic', 'Heritage', 'Organic', 'Brewery',
#        'Live Music', 'Steakhouse', 'Russian', 'Mosque', 'Falls',
#        'Football Field', 'Silk Emporium', 'Sweets', 'Coastal', 'Korma',
#        'Equestrian ', 'Collage', 'Thai', 'Butcher Shop', 'Rajasthani',
#        'Argentinian', 'Coffee', 'Golf Course', 'Upma', 'Moroccan',
#        'Irish', 'Chinese', 'Awadhi', 'Stationery', 'Karaoke Bar',
#        'Fried Chicken ', 'Italian ', 'Khichdi', 'Art Gallery', 'Afghan',
#        'Cold Drinks', 'Rock Climbing ', 'Supplement ', 'Waffle',
#        'Pharmacy', 'Hot Air Balloon', 'Mexican', 'Pakora Stall',
#        'Bhelpuri', 'Paratha Shop', 'Idli', 'Bridge', 'Mutton Biryani',
#        'Uttar Pradesh', 'Poha', 'Seafood ', 'Archaeological Site',
#        'Waterfalls', 'Halotherapy Center', 'Roti Wala', 'Sports Bar',
#        'BBQ', 'Art Supply ', 'Thai ', 'Club', 'Reflexology', 'Tour',
#        'Piano Bar', 'Chaat', 'Mughlai', 'Heritage ', 'Barber', 'Fish ',
#        'Cycling', 'Memorial', 'Tibetan', 'Palak Paneer', 'Wellness ',
#        'Court', 'Badminton Court', 'Gymnasium', 'Street Food ',
#        'Spice Shop', 'Gelateria', 'Bird Watching', 'Maldivian',
#        'Cryotherapy Center', 'Plantations', 'Reserve', 'Beach', 'Buddha',
#        'Music', 'Theater', 'Diving', 'Dosa', 'Bicycle Path', 'Sikkim',
#        'Wine ', 'Australian', 'Beauty Salon', 'Andaman and Nicobar',
#        'Lucknowi', 'Scandinavian', "Farmers' Market", 'Sunset Point',
#        'Bowling Alley', 'None', 'Coffee Roastery', 'Mandir', 'Stepwell',
#        'Guesthouse', 'Herb ', 'Lebanese', 'Race Track', 'Sushi Bar',
#        'Brazilian', 'Nature Park', 'Brewpub', 'Cheese Shop', 'Bhel Puri ',
#        'Kulfi', 'Trade Fair', 'Chiropractic', 'Liquor ', 'Meditation ',
#        'Pulao', 'Hypermarket', 'Middle Eastern', 'Gift Shop', 'Malaysian',
#        'Maqbara', 'Mexican ', 'British', 'Pav Bhaji', 'Gardens',
#        'Cocktail', 'Bagel', 'memorials', 'Theme Park',
#        'Convention Center', 'Bazzar', 'Irani', 'Gujarati', 'Paintball ',
#        'Bookstore', 'Camping', 'Donut ', 'Sikkimese', 'Nail ',
#        'Hyderabadi', 'Bhaji', 'Memorial Hall', 'Floatation Center',
#        'Himachali', 'Caves', 'Parsi', 'Rajma', 'Botanical Garden',
#        'Planetarium', 'Salad Bar', 'Vada', 'Paneer', 'Club House',
#        'Vegetarian', 'Tavern', 'College', 'Fitness', 'Rice Terrace',
#        'Rafting', 'Relaxation ', 'Beer Store', 'Spanish ', 'Meghalayan',
#        'Ethnic', 'Foot Spa', 'Waterfall', 'Biryani ', 'Health Food ',
#        'Adventure Tour', 'Specialty ', 'Swiss', 'Science Centre',
#        'Observatory', 'Popcorn ', 'Smoothie ', 'Vintage ', 'Ashram',
#        'Go-Kart Track', 'Jain', 'Curry', 'Dahi Vada', 'Detox ',
#        'Cosmetics ', 'Beer Garden', 'Nature Trail', 'Barbecue ',
#        'Cricket Ground', 'Scenic Viewpoint', 'Water Park', 'Gulab Jamun ',
#        'Diner', 'Hostel', 'Park', 'Cheesecake', 'Health Club',
#        'Bhindi Masala', 'Brazillian', 'Gajar Halwa', 'Chaat Stall',
#        'Tearoom', 'Basilica', 'Pet Store', 'Lake', 'Church', 'Accessory',
#        'Masala Dosa ', 'Cheesemonger', 'Marine Park', 'Cidery', 'Fishing',
#        'Lodge', 'Chinese Medicine', 'Konkani', 'Sake ', 'Wellness',
#        'Thali', 'Chettinad', 'Tandoori ', 'Massage ', 'Hot Dog ',
#        'Adventure ', 'Mediterranean', 'Tea House', 'Outdoor ',
#        'Sunrise Point', 'Winery', 'American', 'Snacks', 'Vegetable',
#        'Beauty Spa', 'Northeastern', 'Barbecue', 'Gota', 'Saffron Fields',
#        'Causeway', 'Reef', 'Barbeque', 'Butter Chicken', 'Malvani',
#        'Sports Goods ', 'Misal', 'Coconut Chutney', 'Sindhi', 'Israeli',
#        'Mountain Range', 'Picnic Spot', 'Exhibition', 'Odisha',
#        'Vada Pav ', 'Ruins', 'Fish and Chips', 'Karnataka',
#        'Mysore Masala Dosa', 'Iranian', 'Market ', 'Shrine', 'Candy',
#        'Indian ', 'Korean', 'Jacuzzi', 'Kande Pohe', 'Cinema', 'Hiking',
#        'Burger ', 'Chinese ', 'Rehabilitation ', 'Beauty Supply ',
#        'Tamil', 'Locally Sourced ', 'Drinks', 'Kulfi Corner', 'Clothing ',
#        'Canteen', 'Fruit Stand', 'Sweet ', 'Malai Kofta', 'Fondue',
#        'Aloo Tikki', 'Yoga', 'Japanese', 'Street', 'Cultural Tour',
#        'Bathhouse', 'Gym', 'Ski Center', 'Tennis Court', 'Assamese',
#        'Volleyball Court', 'Turkish', 'Café', 'Bicycle Shop', 'Mess',
#        'Punjabi', 'Rainforest', 'Adventure Sports', 'Snorkeling', 'Farm',
#        'Raita', 'Shooting Range', 'Swimming Pool', 'Chocolate',
#        'Food Truck', 'Ice Skating ', 'Tripuri', 'Farmers Market', 'Bread',
#        'Khasi', 'Olive Oil ', 'Dhokla ', 'Night Market', 'Music Store',
#        'Sporthall', 'Boat Tour', 'Boating', 'Massage Center', 'Andhra',
#        'Forest', 'Misal Pav', 'Gastropub', 'Biriyani', 'Harbor', 'Rajput',
#        'Gourmet Market', 'Antique Store', 'Hyderabadi Biryani ',
#        'Sweets ', 'Ramen', 'Skiing', 'Thermal Spa', 'Gulab Jamun',
#        'Sweet', 'Rogan Josh', 'Rajma Chawal ', 'Irish Pub',
#        'Film Festival', 'Salon', 'Pizzeria', 'Riverwalk', 'Kolkata',
#        'Delicatessen', 'Family Entertainment', 'Farm-to-Table ', 'Bhel',
#        'Health Spa', 'Entertainment', 'Kashmiri', 'Samosa ', 'Naga',
#        'Brasserie', 'Confectionery', 'Buffet ', 'Monument', 'Furniture',
#        'Frozen Yogurt ', 'Nature Tour', 'Food Hall', 'Chole Bhature',
#        'Herbal ', 'Supermarket', 'Cultural Center', 'Hill Station',
#        'Wellness Spa', 'Fish Curry', 'Aromatherapy ', 'Temple', 'Castle',
#        'Picnic Garden', 'Bay', 'Fitness Trail', 'Ladakhi', 'Bazaar',
#        'Ghat', 'Bihari', 'National Park', 'Kheer', 'Music Festival',
#        'Wine Bar', 'Vada Pav', 'Promenade', 'Plaza', 'Drive-Thru',
#        'Meat Shop', 'Chocolate ', 'Samosa', 'Mahal', 'Kitchen',
#        'Jamaican', 'Cupcake Shop', 'Skating Rink', 'Pani Puri',
#        'Pyramids', 'Beer', 'Fast Food ', 'Grill', 'Yoga ', 'Spice Farm',
#        'Pakora', 'Chapati', 'Railway Station', 'Fast Food', 'Danish',
#        'Kayaking', 'Basketball Court', 'Campground', 'Gelato', 'Outdoor',
#        'Indoor', 'Mountain', 'Nightclub', 'Shoe Store', 'Field',
#        'Festival', 'Cathedral'], dtype=object)

# %%
df3 = pd.DataFrame({'Tags':actual})

# %%
df3.to_csv('tag_names_for_tag1')

# %%
places_from_names ={
    'Monestry': 'site-seeing',
    'Cruise': 'entertainment',
    'Museum': 'site-seeing',
    'Craft': 'shopping',
    'Mall': 'shopping',
    'Saree': 'shopping',
    'Lounge': 'entertainment',
    'Bhojpuri': 'entertainment',
    'Sauna': 'self-care',
    'Grocery': 'shopping',
    'Sushi': 'food',
    'African': 'food',
    'Snowboarding': 'entertainment',
    'Bar': 'clubs & bar',
    'Indian': 'food',
    'Island': 'site-seeing',
    'Bistro': 'food',
    'Resort': 'entertainment',
    'Peak': 'site-seeing',
    'Thrift Store': 'shopping',
    'Electronics': 'shopping',
    'Sailing': 'entertainment',
    'Airport': 'site-seeing',
    'Bhaji Pav': 'food',
    'Tanning Salon': 'self-care',
    'Tea Shop': 'cafe',
    'Dam': 'site-seeing',
    'Street Food': 'food',
    'Landmark': 'site-seeing',
    'Auto Parts': 'shopping',
    'Shopping Street': 'shopping',
    'Appliance': 'shopping',
    'Convenience': 'shopping',
    'Cocktail Bar': 'clubs & bar',
    'Lassi': 'food',
    'Acupuncture': 'self-care',
    'Specialty Food': 'food',
    'Paratha': 'food',
    'Sanctuary': 'site-seeing',
    'Spa': 'self-care',
    'North Indian': 'food',
    'Garden Center': 'shopping',
    'Pedestrian Street': 'shopping',
    'Kebab': 'food',
    'Kathiyawadi': 'food',
    'Taco': 'food',
    'Oyster': 'food',
    'Oyster Bar': 'food',
    'Sushi Bar': 'food',
    'Cafe': 'cafe',
    'Ethiopian': 'food',
    'Indonesian': 'food',
    'Peruvian': 'food',
    'Hill': 'site-seeing',
    'Archery Range': 'entertainment',
    'Gourmet Food': 'food',
    'Masala Dosa': 'food',
    'Deli': 'food',
    'Outlet': 'shopping',
    'Zoo': 'site-seeing',
    'Computer': 'shopping',
    'Egyptian': 'food',
    'Idli': 'food',
    'Cake': 'dessert',
    'Stargazing Spot': 'site-seeing',
    'Salt Cave': 'self-care',
    'Mindfulness': 'self-care',
    'Masjid': 'site-seeing',
    'English Pub': 'clubs & bar',
    'Statue': 'site-seeing',
    'Mangalorean': 'food',
    'Kadai Paneer': 'food',
    'Locho': 'food',
    'Dessert': 'dessert',
    'Greek': 'food',
    'Pho Noodle': 'food',
    'South Indian': 'food',
    'Ayurvedic': 'self-care',
    'Library': 'site-seeing',
    'Restaurant': 'food',
    'University': 'site-seeing',
    'Flea Market': 'shopping',
    'Kebab': 'food',
    'Chole Bhature': 'food',
    'Garden': 'site-seeing',
    'Infrared Sauna': 'self-care',
    'Buddhist': 'site-seeing',
    'Boutique': 'shopping',
    'Manipuri': 'food',
    'Rasmalai': 'dessert',
    'Amusement Park': 'entertainment',
    'Swedish': 'food',
    'Ski Resort': 'entertainment',
    'Home Decor': 'shopping',
    'Jalebi': 'dessert',
    'Pesarattu': 'food',
    'Roti': 'food',
    'Department Store': 'shopping',
    'Wine Tasting': 'entertainment',
    'Restro': 'food',
    'Retreat Center': 'site-seeing',
    'Greek': 'food',
    'Thali': 'food',
    'Vegan': 'food',
    'Cakery': 'dessert',
    'Chocolatier': 'dessert',
    'Bakery': 'dessert',
    'Dutch': 'food',
    'Paneer Tikka': 'food',
    'Veg': 'food',
    'Juice': 'food',
    'Bengali': 'food',
    'Vav': 'site-seeing',
    'Historical Site': 'site-seeing',
    'River': 'site-seeing',
    'Naan': 'food',
    'Tandoori': 'food',
    'Gurudwara': 'site-seeing',
    'Resort': 'site-seeing',
    'Pani Puri': 'food',
    'Paragliding': 'entertainment',
    'Valley': 'site-seeing',
    'German': 'food',
    'Ice Cream': 'dessert',
    'Pilates': 'self-care',
    'Donuts': 'dessert',
    'Mount': 'site-seeing',
    'Hair Salon': 'self-care',
    'Vineyard': 'site-seeing',
    'Fashion': 'shopping',
    'Goan': 'food',
    'Biryani': 'food',
    'Beaches': 'site-seeing',
    'Kachori': 'food',
    'City Tour': 'site-seeing',
    'Garhwali': 'food',
    'Jodhpuri': 'food',
    'Cheese': 'food',
    'Archaeological Park': 'site-seeing',
    'Day Spa': 'self-care',
    'Jewelry': 'shopping',
    'Drive-In': 'entertainment',
    'Helicopter Tour': 'entertainment',
    'Surfing': 'entertainment',
    'Gallery': 'site-seeing',
    'Market': 'shopping',
    'Italian': 'food',
    'Baker': 'dessert',
    'Beach Shack': 'food',
    'Maharashtrian': 'food',
    'Lighthouse': 'site-seeing',
    'Wildlife': 'site-seeing',
    'Spanish': 'food',
    'Dhaba': 'food',
    'Vietnamese': 'food',
    'Anglo-Indian': 'food',
    'Cave': 'site-seeing',
    'Mizo': 'food',
    'French': 'food',
    'Physical Therapy': 'self-care',
    'Pub': 'clubs & bar',
    'Super Market': 'shopping',
    'Sandwich': 'food',
    'Steam Room': 'self-care',
    'Taproom': 'entertainment',
    'Pastry': 'dessert',
    'Playground': 'entertainment',
    'Video Game': 'entertainment',
    'Fort': 'site-seeing',
    'Toy Store': 'shopping',
    'Fine Dining': 'food',
    'Couture': 'shopping',
    'Malai Kofta': 'food',
    'Opera House': 'entertainment',
    'Food Court': 'food',
    'Hot Springs': 'site-seeing',
    'Food Market': 'food',
    'Noodle': 'food',
    'Photography': 'entertainment',
    'Sports': 'entertainment',
    'Holistic Center': 'self-care',
    'Family': 'entertainment',
    'Safari': 'site-seeing',
    'Historical Tour': 'site-seeing',
    'Rasgulla': 'dessert',
    'Clinic': 'self-care',
    'Heritage': 'site-seeing',
    'Organic': 'food',
    'Brewery': 'clubs & bar',
    'Live Music': 'entertainment',
    'Steakhouse': 'food',
    'Russian': 'food',
    'Mosque': 'site-seeing',
    'Falls': 'site-seeing',
    'Football Field': 'entertainment',
    'Silk Emporium': 'shopping',
    'Sweets': 'dessert',
    'Coastal': 'site-seeing',
    'Korma': 'food',
    'Equestrian': 'entertainment',
    'Thai': 'food',
    'Butcher Shop': 'shopping',
    'Thai massage': 'self-care',
    'Rajasthani': 'food',
    'Argentinian': 'food',
    'Coffee': 'food',
    'Golf Course': 'sports',
    'Upma': 'food',
    'Moroccan': 'food',
    'Chinese': 'food',
    'Awadhi': 'food',
    'Stationery': 'shopping',
    'Karaoke Bar': 'entertainment',
    'Fried Chicken': 'food',
    'Italian': 'food',
    'Khichdi': 'food',
    'Art Gallery': 'site-seeing',
    'Afghan': 'food',
    'Cold Drinks': 'food',
    'Rock Climbing': 'entertainment',
    'Supplement': 'shopping',
    'Waffle': 'dessert',
    'Pharmacy': 'self-care',
    'Hot Air Balloon': 'entertainment',
    'Mexican': 'food',
    'Pakora': 'food',
    'Bhelpuri': 'food',
    'Paratha Shop': 'food',
    'Idli': 'food',
    'Bridge': 'site-seeing',
    'Mutton Biryani': 'food',
    'Poha': 'food',
    'Seafood': 'food',
    'Archaeological Site': 'site-seeing',
    'Waterfalls': 'site-seeing',
    'Halotherapy Center': 'self-care',
    'Roti': 'food',
    'Sports Bar': 'clubs & bar',
    'BBQ': 'food',
    'Art Supply': 'shopping',
    'Thai': 'food',
    'Club': 'entertainment',
    'Reflexology': 'self-care',
    'Tour': 'site-seeing',
    'Piano Bar': 'clubs & bar',
    'Chaat': 'food',
    'Mughlai': 'food',
    'Heritage': 'site-seeing',
    'Barber': 'self-care',
    'Fish': 'food',
    'Memorial': 'site-seeing',
    'Tibetan': 'food',
    'Palak Paneer': 'food',
    'Wellness': 'self-care',
    'Court': 'entertainment',
    'Badminton Court': 'sports',
    'Gymnasium': 'sports',
    'Street Food': 'food',
    'Spice Shop': 'shopping',
    'Gelateria': 'food',
    'Bird Watching': 'site-seeing',
    'Maldivian': 'food',
    'Cryotherapy Center': 'self-care',
    'Plantations': 'site-seeing',
    'Reserve': 'site-seeing',
    'Beach': 'site-seeing',
    'Buddha': 'site-seeing',
    'Music': 'entertainment',
    'Theater': 'entertainment',
    'Diving': 'entertainment',
    'Dosa': 'food',
    'Sikkim': 'site-seeing',
    'Wine': 'food',
    'Australian': 'food',
    'Beauty Salon': 'self-care',
    'Andaman and Nicobar': 'site-seeing',
    'Lucknowi': 'food',
    'Scandinavian': 'food',
    "Farmers' Market": 'shopping',
    'Sunset Point': 'site-seeing',
    'Bowling Alley': 'entertainment',
    'None': 'uncategorized',
    'Mandir': 'site-seeing',
    'Stepwell': 'site-seeing',
    'Herb': 'food',
    'Lebanese': 'food',
    'Race Track': 'entertainment',
    'Sushi Bar': 'food',
    'Brazilian': 'food',
    'Nature Park': 'site-seeing',
    'Brewpub': 'clubs & bar',
    'Cheese Shop': 'food',
    'Bhel Puri': 'food',
    'Kulfi': 'dessert',
    'Chiropractic': 'self-care',
    'Meditation': 'self-care',
    'Pulao': 'food',
    'Hypermarket': 'shopping',
    'Middle Eastern': 'food',
    'Gift Shop': 'shopping',
    'Malaysian': 'food',
    'Maqbara': 'site-seeing',
    'Mexican': 'food',
    'British': 'food',
    'Pav Bhaji': 'food',
    'Gardens': 'site-seeing',
    'Cocktail': 'clubs & bar',
    'Bagel': 'food',
    'memorials': 'site-seeing',
    'Theme Park': 'entertainment',
    'Bazzar': 'shopping',
    'Irani': 'food',
    'Gujarati': 'food',
    'Bookstore': 'shopping',
    'Donut': 'dessert',
    'Sikkimese': 'food',
    'Nail': 'self-care',
    'Hyderabadi': 'food',
    'Bhaji': 'food',
    'Memorial Hall': 'site-seeing',
    'Floatation Center': 'self-care',
    'Himachali': 'food',
    'Caves': 'site-seeing',
    'Parsi': 'food',
    'Rajma': 'food',
    'Botanical Garden': 'site-seeing',
    'Planetarium': 'site-seeing',
    'Salad Bar': 'food',
    'Vada': 'food',
    'Paneer': 'food',
    'Club House': 'entertainment',
    'Vegetarian': 'food',
    'College': 'site-seeing',
    'Fitness':'self-care',
    'Rice Terrace': 'site-seeing',
    'Rafting': 'entertainment',
    'Relaxation': 'self-care',
    'Beer Store': 'Shopping',
    'Spanish': 'food',
    'Meghalayan': 'food',
    'Ethnic': 'food',
    'Foot Spa': 'self-care',
    'Waterfall': 'site-seeing',
    'Biryani': 'food',
    'Health Food': 'food',
    'Adventure Tour': 'entertainment',
    'Swiss': 'food',
    'Science Centre': 'site-seeing',
    'Observatory': 'site-seeing',
    'Popcorn': 'food',
    'Smoothie': 'food',
    'Vintage': 'site-seeing',
    'Ashram': 'site-seeing',
    'Jain': 'food',
    'Curry': 'food',
    'Dahi Vada': 'food',
    'Detox': 'self-care',
    'Cosmetics': 'shopping',
    'Beer Garden': 'food',
    'Nature Trail': 'site-seeing',
    'Barbecue': 'food',
    'Cricket Ground': 'entertainment',
    'Scenic Viewpoint': 'site-seeing',
    'Water Park': 'entertainment',
    'Gulab Jamun': 'dessert',
    'Diner': 'food',
    'Park': 'site-seeing',
    'Cheesecake': 'dessert',
    'Health Club': 'self-care',
    'Bhindi Masala': 'food',
    'Brazillian': 'food',
    'Gajar Halwa': 'dessert',
    'Chaat': 'food',
    'Tearoom': 'cafe',
    'Basilica': 'site-seeing',
    'Pet Store': 'shopping',
    'Lake': 'site-seeing',
    'Church': 'site-seeing',
    'Accessory': 'shopping',
    'Masala Dosa': 'food',
    'Cheesemonger': 'food',
    'Marine Park': 'site-seeing',
    'Fishing': 'entertainment',
    'Lodge': 'entertainment',
    'Chinese Medicine': 'self-care',
    'Konkani': 'food',
    'Sake': 'beverage',
    'Wellness': 'self-care',
    'Thali': 'food',
    'Chettinad': 'food',
    'Tandoori': 'food',
    'Massage': 'self-care',
    'Hot Dog': 'food',
    'Adventure': 'entertainment',
    'Mediterranean': 'food',
    'Tea House': 'cafe',
    'Outdoor Arena': 'entertainmnet',
    'Sunrise Point': 'site-seeing',
    'Winery': 'food',
    'American': 'food',
    'Snacks': 'food',
    'Vegetable': 'food',
    'Beauty Spa': 'self-care',
    'Northeastern': 'food',
    'Barbecue': 'food',
    'Gota': 'food',
    'Saffron Fields': 'site-seeing',
    'Causeway': 'site-seeing',
    'Reef': 'site-seeing',
    'Barbeque': 'food',
    'Butter Chicken': 'food',
    'Malvani': 'food',
    'Sports Goods': 'shopping',
    'Misal': 'food',
    'Coconut Chutney': 'food',
    'Sindhi': 'food',
    'Israeli': 'food',
    'Mountain Range': 'site-seeing',
    'Picnic Spot': 'site-seeing',
    'Exhibition': 'site-seeing',
    'Odisha': 'food',
    'Vada Pav': 'food',
    'Ruins': 'site-seeing',
    'Fish and Chips': 'food',
    'Karnataka': 'food',
    'Mysore Masala Dosa': 'food',
    'Iranian': 'food',
    'Market': 'shopping',
    'Shrine': 'site-seeing',
    'Candy': 'dessert',
    'Indian': 'food',
    'Korean': 'food',
    'Jacuzzi': 'self-care',
    'Kande Pohe': 'food',
    'Cinema': 'entertainment',
    'Burger': 'food',
    'Chinese': 'food',
    'Rehabilitation': 'self-care',
    'Beauty Supply': 'shopping',
    'Tamil': 'food',
    'Locally Sourced': 'food',
    'Drinks': 'beverage',
    'Kulfi Corner': 'dessert',
    'Clothing': 'shopping',
    'Canteen': 'food',
    'Fruit Stand': 'food',
    'Sweet': 'dessert',
    'Malai Kofta': 'food',
    'Fondue': 'food',
    'Aloo Tikki': 'food',
    'Yoga': 'self-care',
    'Japanese': 'food',
    'Street': 'site-seeing',
    'Cultural Tour': 'site-seeing',
    'Bathhouse': 'self-care',
    'Gym': 'self-care',
    'Ski Center': 'entertainment',
    'Tennis Court': 'entertainment',
    'Assamese': 'food',
    'Volleyball Court': 'entertainment',
    'Turkish': 'food',
    'Café': 'cafe',
    'Bicycle Shop': 'shopping',
    'Mess': 'food',
    'Punjabi': 'food',
    'Rainforest': 'site-seeing',
    'Sports':'entertainmnet',
    'Shooting Range': 'entertainmnet',
    'Swimming Pool': 'entertainmnet',
    'Chocolate': 'dessert',
    'Food Truck': 'food',
    'Ice Skating': 'entertainmnet',
    'Tripuri': 'food',
    'Farmers Market': 'shopping',
    'Bread': 'food',
    'Khasi': 'food',
    'Dhokla': 'food',
    'Night Market': 'shopping',
    'Music Store': 'shopping',
    'Sporthall': 'entertainmnet',
    'Boat Tour': 'site-seeing',
    'Boating': 'entertainmnet',
    'Massage Center': 'self-care',
    'Andhra': 'food',
    'Forest': 'site-seeing',
    'Misal Pav': 'food',
    'Gastropub': 'food',
    'Biriyani': 'food',
    'Harbor': 'site-seeing',
    'Gourmet Market': 'shopping',
    'Antique Store': 'shopping',
    'Hyderabadi Biryani': 'food',
    'Sweets': 'dessert',
    'Ramen': 'food',
    'Skiing': 'entertainmnet',
    'Thermal Spa': 'self-care',
    'Gulab Jamun': 'dessert',
    'Rogan Josh': 'food',
    'Rajma Chawal': 'food',
    'Irish Pub': 'clubs & bar',
    'Film Festival': 'entertainment',
    'Salon': 'self-care',
    'Pizzeria': 'food',
    'Riverwalk': 'site-seeing',
    'Delicatessen': 'food',
    'Family Entertainment': 'entertainment',
    'Farm-to-Table': 'food',
    'Bhel': 'food',
    'Health Spa': 'self-care',
    'Entertainment': 'entertainment',
    'Kashmiri': 'food',
    'Samosa': 'food',
    'Naga': 'food',
    'Brasserie': 'food',
    'Confectionery': 'food',
    'Buffet': 'food',
    'Monument': 'site-seeing',
    'Furniture': 'shopping',
    'Frozen Yogurt': 'food',
    'Nature Tour': 'site-seeing',
    'Food Hall': 'food',
    'Chole Bhature': 'food',
    'Herbal': 'self-care',
    'Supermarket': 'shopping',
    'Cultural Center': 'site-seeing',
    'Hill Station': 'site-seeing',
    'Wellness': 'self-care',
    'Fish Curry': 'food',
    'Aromatherapy': 'self-care',
    'Temple': 'site-seeing',
    'Castle': 'site-seeing',
    'Picnic Garden': 'site-seeing',
    'Bay': 'site-seeing',
    'Ladakhi': 'food',
    'Bazaar': 'shopping',
    'Ghat': 'site-seeing',
    'Bihari': 'food',
    'National Park': 'site-seeing',
    'Kheer': 'dessert',
    'Music Festival': 'entertainment',
    'Wine Bar': 'clubs & bar',
    'Vada Pav': 'food',
    'Promenade': 'site-seeing',
    'Plaza': 'Shopping',
    'Drive-Thru': 'food',
    'Meat Shop': 'food',
    'Chocolate': 'dessert',
    'Mahal': 'site-seeing',
    'Kitchen': 'food',
    'Jamaican': 'food',
    'Cupcake Shop': 'food',
    'Skating Rink': 'entertainmnet',
    'Pani Puri': 'food',
    'Pyramids': 'site-seeing',
    'Beer': 'clubs & bar',
    'Fast Food': 'food',
    'Grill': 'food',
    'Yoga': 'self-care',
    'Spice Farm': 'site-seeing',
    'Pakora': 'food',
    'Chapati': 'food',
    'Railway Station': 'site-seeing',
    'Danish': 'food',
    'Kayaking': 'entertainmnet',
    'Basketball Court': 'entertainmnet',
    'Campground': 'site-seeing',
    'Stadium': 'entertainmnet',
    'Gelato': 'dessert',
    'Mountain': 'site-seeing',
    'Nightclub': 'clubs & bar',
    'Shoe Store': 'shopping',
    'Field': 'site-seeing',
    'Festival': 'entertainment',
    'Cathedral': 'site-seeing'
}

# %%
names = list(places_from_names.keys())

# %%
type(names)
# Out:
# list

# %%
all_tags = list(set(names))

# %%
len(all_tags)
# Out:
# 541

# %%
df3 = pd.DataFrame({'Tags':all_tags})

# %%
places_from_names
# Out:
# {'Monestry': 'site-seeing',
#  'Cruise': 'entertainment',
#  'Museum': 'site-seeing',
#  'Craft': 'shopping',
#  'Mall': 'shopping',
#  'Saree': 'shopping',
#  'Lounge': 'entertainment',
#  'Bhojpuri': 'entertainment',
#  'Sauna': 'self-care',
#  'Grocery': 'shopping',
#  'Sushi': 'food',
#  'African': 'food',
#  'Snowboarding': 'entertainment',
#  'Bar': 'clubs & bar',
#  'Indian': 'food',
#  'Island': 'site-seeing',
#  'Bistro': 'food',
#  'Resort': 'site-seeing',
#  'Peak': 'site-seeing',
#  'Thrift Store': 'shopping',
#  'Electronics': 'shopping',
#  'Sailing': 'entertainment',
#  'Airport': 'site-seeing',
#  'Bhaji Pav': 'food',
#  'Tanning Salon': 'self-care',
#  'Tea Shop': 'cafe',
#  'Dam': 'site-seeing',
#  'Street Food': 'food',
#  'Landmark': 'site-seeing',
#  'Auto Parts': 'shopping',
#  'Shopping Street': 'shopping',
#  'Appliance': 'shopping',
#  'Convenience': 'shopping',
#  'Cocktail Bar': 'clubs & bar',
#  'Lassi': 'food',
#  'Acupuncture': 'self-care',
#  'Specialty Food': 'food',
#  'Paratha': 'food',
#  'Sanctuary': 'site-seeing',
#  'Spa': 'self-care',
#  'North Indian': 'food',
#  'Garden Center': 'shopping',
#  'Pedestrian Street': 'shopping',
#  'Kebab': 'food',
#  'Kathiyawadi': 'food',
#  'Taco': 'food',
#  'Oyster': 'food',
#  'Oyster Bar': 'food',
#  'Sushi Bar': 'food',
#  'Cafe': 'cafe',
#  'Ethiopian': 'food',
#  'Indonesian': 'food',
#  'Peruvian': 'food',
#  'Hill': 'site-seeing',
#  'Archery Range': 'entertainment',
#  'Gourmet Food': 'food',
#  'Masala Dosa': 'food',
#  'Deli': 'food',
#  'Outlet': 'shopping',
#  'Zoo': 'site-seeing',
#  'Computer': 'shopping',
#  'Egyptian': 'food',
#  'Idli': 'food',
#  'Cake': 'dessert',
#  'Stargazing Spot': 'site-seeing',
#  'Salt Cave': 'self-care',
#  'Mindfulness': 'self-care',
#  'Masjid': 'site-seeing',
#  'English Pub': 'clubs & bar',
#  'Statue': 'site-seeing',
#  'Mangalorean': 'food',
#  'Kadai Paneer': 'food',
#  'Locho': 'food',
#  'Dessert': 'dessert',
#  'Greek': 'food',
#  'Pho Noodle': 'food',
#  'South Indian': 'food',
#  'Ayurvedic': 'self-care',
#  'Library': 'site-seeing',
#  'Restaurant': 'food',
#  'University': 'site-seeing',
#  'Flea Market': 'shopping',
#  'Chole Bhature': 'food',
#  'Garden': 'site-seeing',
#  'Infrared Sauna': 'self-care',
#  'Buddhist': 'site-seeing',
#  'Boutique': 'shopping',
#  'Manipuri': 'food',
#  'Rasmalai': 'dessert',
#  'Amusement Park': 'entertainment',
#  'Swedish': 'food',
#  'Ski Resort': 'entertainment',
#  'Home Decor': 'shopping',
#  'Jalebi': 'dessert',
#  'Pesarattu': 'food',
#  'Roti': 'food',
#  'Department Store': 'shopping',
#  'Wine Tasting': 'entertainment',
#  'Restro': 'food',
#  'Retreat Center': 'site-seeing',
#  'Thali': 'food',
#  'Vegan': 'food',
#  'Cakery': 'dessert',
#  'Chocolatier': 'dessert',
#  'Bakery': 'dessert',
#  'Dutch': 'food',
#  'Paneer Tikka': 'food',
#  'Veg': 'food',
#  'Juice': 'food',
#  'Bengali': 'food',
#  'Vav': 'site-seeing',
#  'Historical Site': 'site-seeing',
#  'River': 'site-seeing',
#  'Naan': 'food',
#  'Tandoori': 'food',
#  'Gurudwara': 'site-seeing',
#  'Pani Puri': 'food',
#  'Paragliding': 'entertainment',
#  'Valley': 'site-seeing',
#  'German': 'food',
#  'Ice Cream': 'dessert',
#  'Pilates': 'self-care',
#  'Donuts': 'dessert',
#  'Mount': 'site-seeing',
#  'Hair Salon': 'self-care',
#  'Vineyard': 'site-seeing',
#  'Fashion': 'shopping',
#  'Goan': 'food',
#  'Biryani': 'food',
#  'Beaches': 'site-seeing',
#  'Kachori': 'food',
#  'City Tour': 'site-seeing',
#  'Garhwali': 'food',
#  'Jodhpuri': 'food',
#  'Cheese': 'food',
#  'Archaeological Park': 'site-seeing',
#  'Day Spa': 'self-care',
#  'Jewelry': 'shopping',
#  'Drive-In': 'entertainment',
#  'Helicopter Tour': 'entertainment',
#  'Surfing': 'entertainment',
#  'Gallery': 'site-seeing',
#  'Market': 'shopping',
#  'Italian': 'food',
#  'Baker': 'dessert',
#  'Beach Shack': 'food',
#  'Maharashtrian': 'food',
#  'Lighthouse': 'site-seeing',
#  'Wildlife': 'site-seeing',
#  'Spanish': 'food',
#  'Dhaba': 'food',
#  'Vietnamese': 'food',
#  'Anglo-Indian': 'food',
#  'Cave': 'site-seeing',
#  'Mizo': 'food',
#  'French': 'food',
#  'Physical Therapy': 'self-care',
#  'Pub': 'clubs & bar',
#  'Super Market': 'shopping',
#  'Sandwich': 'food',
#  'Steam Room': 'self-care',
#  'Taproom': 'entertainment',
#  'Pastry': 'dessert',
#  'Playground': 'entertainment',
#  'Video Game': 'entertainment',
#  'Fort': 'site-seeing',
#  'Toy Store': 'shopping',
#  'Fine Dining': 'food',
#  'Couture': 'shopping',
#  'Malai Kofta': 'food',
#  'Opera House': 'entertainment',
#  'Food Court': 'food',
#  'Hot Springs': 'site-seeing',
#  'Food Market': 'food',
#  'Noodle': 'food',
#  'Photography': 'entertainment',
#  'Sports': 'entertainmnet',
#  'Holistic Center': 'self-care',
#  'Family': 'entertainment',
#  'Safari': 'site-seeing',
#  'Historical Tour': 'site-seeing',
#  'Rasgulla': 'dessert',
#  'Clinic': 'self-care',
#  'Heritage': 'site-seeing',
#  'Organic': 'food',
#  'Brewery': 'clubs & bar',
#  'Live Music': 'entertainment',
#  'Steakhouse': 'food',
#  'Russian': 'food',
#  'Mosque': 'site-seeing',
#  'Falls': 'site-seeing',
#  'Football Field': 'entertainment',
#  'Silk Emporium': 'shopping',
#  'Sweets': 'dessert',
#  'Coastal': 'site-seeing',
#  'Korma': 'food',
#  'Equestrian': 'entertainment',
#  'Thai': 'food',
#  'Butcher Shop': 'shopping',
#  'Thai massage': 'self-care',
#  'Rajasthani': 'food',
#  'Argentinian': 'food',
#  'Coffee': 'food',
#  'Golf Course': 'sports',
#  'Upma': 'food',
#  'Moroccan': 'food',
#  'Chinese': 'food',
#  'Awadhi': 'food',
#  'Stationery': 'shopping',
#  'Karaoke Bar': 'entertainment',
#  'Fried Chicken': 'food',
#  'Khichdi': 'food',
#  'Art Gallery': 'site-seeing',
#  'Afghan': 'food',
#  'Cold Drinks': 'food',
#  'Rock Climbing': 'entertainment',
#  'Supplement': 'shopping',
#  'Waffle': 'dessert',
#  'Pharmacy': 'self-care',
#  'Hot Air Balloon': 'entertainment',
#  'Mexican': 'food',
#  'Pakora': 'food',
#  'Bhelpuri': 'food',
#  'Paratha Shop': 'food',
#  'Bridge': 'site-seeing',
#  'Mutton Biryani': 'food',
#  'Poha': 'food',
#  'Seafood': 'food',
#  'Archaeological Site': 'site-seeing',
#  'Waterfalls': 'site-seeing',
#  'Halotherapy Center': 'self-care',
#  'Sports Bar': 'clubs & bar',
#  'BBQ': 'food',
#  'Art Supply': 'shopping',
#  'Club': 'entertainment',
#  'Reflexology': 'self-care',
#  'Tour': 'site-seeing',
#  'Piano Bar': 'clubs & bar',
#  'Chaat': 'food',
#  'Mughlai': 'food',
#  'Barber': 'self-care',
#  'Fish': 'food',
#  'Memorial': 'site-seeing',
#  'Tibetan': 'food',
#  'Palak Paneer': 'food',
#  'Wellness': 'self-care',
#  'Court': 'entertainment',
#  'Badminton Court': 'sports',
#  'Gymnasium': 'sports',
#  'Spice Shop': 'shopping',
#  'Gelateria': 'food',
#  'Bird Watching': 'site-seeing',
#  'Maldivian': 'food',
#  'Cryotherapy Center': 'self-care',
#  'Plantations': 'site-seeing',
#  'Reserve': 'site-seeing',
#  'Beach': 'site-seeing',
#  'Buddha': 'site-seeing',
#  'Music': 'entertainment',
#  'Theater': 'entertainment',
#  'Diving': 'entertainment',
#  'Dosa': 'food',
#  'Sikkim': 'site-seeing',
#  'Wine': 'food',
#  'Australian': 'food',
#  'Beauty Salon': 'self-care',
#  'Andaman and Nicobar': 'site-seeing',
#  'Lucknowi': 'food',
#  'Scandinavian': 'food',
#  "Farmers' Market": 'shopping',
#  'Sunset Point': 'site-seeing',
#  'Bowling Alley': 'entertainment',
#  'None': 'uncategorized',
#  'Mandir': 'site-seeing',
#  'Stepwell': 'site-seeing',
#  'Herb': 'food',
#  'Lebanese': 'food',
#  'Race Track': 'entertainment',
#  'Brazilian': 'food',
#  'Nature Park': 'site-seeing',
#  'Brewpub': 'clubs & bar',
#  'Cheese Shop': 'food',
#  'Bhel Puri': 'food',
#  'Kulfi': 'dessert',
#  'Chiropractic': 'self-care',
#  'Meditation': 'self-care',
#  'Pulao': 'food',
#  'Hypermarket': 'shopping',
#  'Middle Eastern': 'food',
#  'Gift Shop': 'shopping',
#  'Malaysian': 'food',
#  'Maqbara': 'site-seeing',
#  'British': 'food',
#  'Pav Bhaji': 'food',
#  'Gardens': 'site-seeing',
#  'Cocktail': 'clubs & bar',
#  'Bagel': 'food',
#  'memorials': 'site-seeing',
#  'Theme Park': 'entertainment',
#  'Bazzar': 'shopping',
#  'Irani': 'food',
#  'Gujarati': 'food',
#  'Bookstore': 'shopping',
#  'Donut': 'dessert',
#  'Sikkimese': 'food',
#  'Nail': 'self-care',
#  'Hyderabadi': 'food',
#  'Bhaji': 'food',
#  'Memorial Hall': 'site-seeing',
#  'Floatation Center': 'self-care',
#  'Himachali': 'food',
#  'Caves': 'site-seeing',
#  'Parsi': 'food',
#  'Rajma': 'food',
#  'Botanical Garden': 'site-seeing',
#  'Planetarium': 'site-seeing',
#  'Salad Bar': 'food',
#  'Vada': 'food',
#  'Paneer': 'food',
#  'Club House': 'entertainment',
#  'Vegetarian': 'food',
#  'College': 'site-seeing',
#  'Fitness': 'self-care',
#  'Rice Terrace': 'site-seeing',
#  'Rafting': 'entertainment',
#  'Relaxation': 'self-care',
#  'Beer Store': 'Shopping',
#  'Meghalayan': 'food',
#  'Ethnic': 'food',
#  'Foot Spa': 'self-care',
#  'Waterfall': 'site-seeing',
#  'Health Food': 'food',
#  'Adventure Tour': 'entertainment',
#  'Swiss': 'food',
#  'Science Centre': 'site-seeing',
#  'Observatory': 'site-seeing',
#  'Popcorn': 'food',
#  'Smoothie': 'food',
#  'Vintage': 'site-seeing',
#  'Ashram': 'site-seeing',
#  'Jain': 'food',
#  'Curry': 'food',
#  'Dahi Vada': 'food',
#  'Detox': 'self-care',
#  'Cosmetics': 'shopping',
#  'Beer Garden': 'food',
#  'Nature Trail': 'site-seeing',
#  'Barbecue': 'food',
#  'Cricket Ground': 'entertainment',
#  'Scenic Viewpoint': 'site-seeing',
#  'Water Park': 'entertainment',
#  'Gulab Jamun': 'dessert',
#  'Diner': 'food',
#  'Park': 'site-seeing',
#  'Cheesecake': 'dessert',
#  'Health Club': 'self-care',
#  'Bhindi Masala': 'food',
#  'Brazillian': 'food',
#  'Gajar Halwa': 'dessert',
#  'Tearoom': 'cafe',
#  'Basilica': 'site-seeing',
#  'Pet Store': 'shopping',
#  'Lake': 'site-seeing',
#  'Church': 'site-seeing',
#  'Accessory': 'shopping',
#  'Cheesemonger': 'food',
#  'Marine Park': 'site-seeing',
#  'Fishing': 'entertainment',
#  'Lodge': 'entertainment',
#  'Chinese Medicine': 'self-care',
#  'Konkani': 'food',
#  'Sake': 'beverage',
#  'Chettinad': 'food',
#  'Massage': 'self-care',
#  'Hot Dog': 'food',
#  'Adventure': 'entertainment',
#  'Mediterranean': 'food',
#  'Tea House': 'cafe',
#  'Outdoor Arena': 'entertainmnet',
#  'Sunrise Point': 'site-seeing',
#  'Winery': 'food',
#  'American': 'food',
#  'Snacks': 'food',
#  'Vegetable': 'food',
#  'Beauty Spa': 'self-care',
#  'Northeastern': 'food',
#  'Gota': 'food',
#  'Saffron Fields': 'site-seeing',
#  'Causeway': 'site-seeing',
#  'Reef': 'site-seeing',
#  'Barbeque': 'food',
#  'Butter Chicken': 'food',
#  'Malvani': 'food',
#  'Sports Goods': 'shopping',
#  'Misal': 'food',
#  'Coconut Chutney': 'food',
#  'Sindhi': 'food',
#  'Israeli': 'food',
#  'Mountain Range': 'site-seeing',
#  'Picnic Spot': 'site-seeing',
#  'Exhibition': 'site-seeing',
#  'Odisha': 'food',
#  'Vada Pav': 'food',
#  'Ruins': 'site-seeing',
#  'Fish and Chips': 'food',
#  'Karnataka': 'food',
#  'Mysore Masala Dosa': 'food',
#  'Iranian': 'food',
#  'Shrine': 'site-seeing',
#  'Candy': 'dessert',
#  'Korean': 'food',
#  'Jacuzzi': 'self-care',
#  'Kande Pohe': 'food',
#  'Cinema': 'entertainment',
#  'Burger': 'food',
#  'Rehabilitation': 'self-care',
#  'Beauty Supply': 'shopping',
#  'Tamil': 'food',
#  'Locally Sourced': 'food',
#  'Drinks': 'beverage',
#  'Kulfi Corner': 'dessert',
#  'Clothing': 'shopping',
#  'Canteen': 'food',
#  'Fruit Stand': 'food',
#  'Sweet': 'dessert',
#  'Fondue': 'food',
#  'Aloo Tikki': 'food',
#  'Yoga': 'self-care',
#  'Japanese': 'food',
#  'Street': 'site-seeing',
#  'Cultural Tour': 'site-seeing',
#  'Bathhouse': 'self-care',
#  'Gym': 'self-care',
#  'Ski Center': 'entertainment',
#  'Tennis Court': 'entertainment',
#  'Assamese': 'food',
#  'Volleyball Court': 'entertainment',
#  'Turkish': 'food',
#  'Café': 'cafe',
#  'Bicycle Shop': 'shopping',
#  'Mess': 'food',
#  'Punjabi': 'food',
#  'Rainforest': 'site-seeing',
#  'Shooting Range': 'entertainmnet',
#  'Swimming Pool': 'entertainmnet',
#  'Chocolate': 'dessert',
#  'Food Truck': 'food',
#  'Ice Skating': 'entertainmnet',
#  'Tripuri': 'food',
#  'Farmers Market': 'shopping',
#  'Bread': 'food',
#  'Khasi': 'food',
#  'Dhokla': 'food',
#  'Night Market': 'shopping',
#  'Music Store': 'shopping',
#  'Sporthall': 'entertainmnet',
#  'Boat Tour': 'site-seeing',
#  'Boating': 'entertainmnet',
#  'Massage Center': 'self-care',
#  'Andhra': 'food',
#  'Forest': 'site-seeing',
#  'Misal Pav': 'food',
#  'Gastropub': 'food',
#  'Biriyani': 'food',
#  'Harbor': 'site-seeing',
#  'Gourmet Market': 'shopping',
#  'Antique Store': 'shopping',
#  'Hyderabadi Biryani': 'food',
#  'Ramen': 'food',
#  'Skiing': 'entertainmnet',
#  'Thermal Spa': 'self-care',
#  'Rogan Josh': 'food',
#  'Rajma Chawal': 'food',
#  'Irish Pub': 'clubs & bar',
#  'Film Festival': 'entertainment',
#  'Salon': 'self-care',
#  'Pizzeria': 'food',
#  'Riverwalk': 'site-seeing',
#  'Delicatessen': 'food',
#  'Family Entertainment': 'entertainment',
#  'Farm-to-Table': 'food',
#  'Bhel': 'food',
#  'Health Spa': 'self-care',
#  'Entertainment': 'entertainment',
#  'Kashmiri': 'food',
#  'Samosa': 'food',
#  'Naga': 'food',
#  'Brasserie': 'food',
#  'Confectionery': 'food',
#  'Buffet': 'food',
#  'Monument': 'site-seeing',
#  'Furniture': 'shopping',
#  'Frozen Yogurt': 'food',
#  'Nature Tour': 'site-seeing',
#  'Food Hall': 'food',
#  'Herbal': 'self-care',
#  'Supermarket': 'shopping',
#  'Cultural Center': 'site-seeing',
#  'Hill Station': 'site-seeing',
#  'Fish Curry': 'food',
#  'Aromatherapy': 'self-care',
#  'Temple': 'site-seeing',
#  'Castle': 'site-seeing',
#  'Picnic Garden': 'site-seeing',
#  'Bay': 'site-seeing',
#  'Ladakhi': 'food',
#  'Bazaar': 'shopping',
#  'Ghat': 'site-seeing',
#  'Bihari': 'food',
#  'National Park': 'site-seeing',
#  'Kheer': 'dessert',
#  'Music Festival': 'entertainment',
#  'Wine Bar': 'clubs & bar',
#  'Promenade': 'site-seeing',
#  'Plaza': 'Shopping',
#  'Drive-Thru': 'food',
#  'Meat Shop': 'food',
#  'Mahal': 'site-seeing',
#  'Kitchen': 'food',
#  'Jamaican': 'food',
#  'Cupcake Shop': 'food',
#  'Skating Rink': 'entertainmnet',
#  'Pyramids': 'site-seeing',
#  'Beer': 'clubs & bar',
#  'Fast Food': 'food',
#  'Grill': 'food',
#  'Spice Farm': 'site-seeing',
#  'Chapati': 'food',
#  'Railway Station': 'site-seeing',
#  'Danish': 'food',
#  'Kayaking': 'entertainmnet',
#  'Basketball Court': 'entertainmnet',
#  'Campground': 'site-seeing',
#  'Stadium': 'entertainmnet',
#  'Gelato': 'dessert',
#  'Mountain': 'site-seeing',
#  'Nightclub': 'clubs & bar',
#  'Shoe Store': 'shopping',
#  'Field': 'site-seeing',
#  'Festival': 'entertainment',
#  'Cathedral': 'site-seeing'}

# %%
keys = list(places_from_names.keys())
values = list(places_from_names.values())

# %%
len(keys)
# Out:
# 541

# %%
len(values)
# Out:
# 541

# %%
df4 = pd.DataFrame({'Tags':keys, 'Category': values})

# %%
df4
# Out:
#            Tags       Category
# 0      Monestry    site-seeing
# 1        Cruise  entertainment
# 2        Museum    site-seeing
# 3         Craft       shopping
# 4          Mall       shopping
# ..          ...            ...
# 536   Nightclub    clubs & bar
# 537  Shoe Store       shopping
# 538       Field    site-seeing
# 539    Festival  entertainment
# 540   Cathedral    site-seeing
#
# [541 rows x 2 columns]

# %%
df4.to_csv('tag_name_list.csv')
